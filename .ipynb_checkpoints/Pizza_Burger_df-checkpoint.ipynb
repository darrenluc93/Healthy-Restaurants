# %%
import pandas as pd
import requests
import json
import numpy as np

# %%
food_types = pd.read_csv('austin_restaurants_nutritionix.csv')
food_types
# Out:
#      Unnamed: 0  Unnamed: 0.1                 name                  brand_id  \
# 0             0             0         Jimmy John's  513fbc1283aa2dc80c000054
# 1             1             1          Blaze Pizza  521b95434a56d006cae2970c
# 2             2             2            Starbucks  513fbc1283aa2dc80c00001f
# 3             3             3   The Capital Grille  569eb7064c054b485d362578
# 4             4             4            Starbucks  513fbc1283aa2dc80c00001f
# ..          ...           ...                  ...                       ...
# 395          95            95           Applebee's  513fbc1283aa2dc80c000015
# 396          96            96          Chick-fil-A  513fbc1283aa2dc80c000025
# 397          97            97               Subway  513fbc1283aa2dc80c000005
# 398          98            98  Bill Miller Bar-B-Q  513fbc1283aa2dc80c00017b
# 399          99            99            Pizza Hut  513fbc1283aa2dc80c000009
#
# ...

# %%
food_types['name'].nunique()
# Out:
# 108

# %%
restaurant_names = food_types['name'].unique()
ddrestaurant_names
# Out:
# array(["Jimmy John's", 'Blaze Pizza', 'Starbucks', 'The Capital Grille',
#        "Uncle Julio's", 'Chipotle', 'Subway', 'Which Wich', "Mama Fu's",
#        'Planet Sub', "Quizno's", 'Thundercloud Subs', "Gatti's Pizza",
#        "PF Chang's", 'Fogo De Chao Churrascaria',
#        'Freebirds World Burrito', "Wendy's", 'Hooters', 'The Coffee Bean',
#        'Whataburger', 'Pollo Tropical', 'Cinnabon', 'Pizza Hut',
#        "Papa John's", "McDonald's", "Raising Cane's", 'TCBY',
#        'Chick-fil-A', "Domino's", 'Taco Cabana', "Schlotzsky's",
#        'Taco Bell', "Church's Chicken", "Joe's Crab Shack", "Chuy's",
#        'Red Mango', 'Jamba Juice', 'Panda Express',
#        'Potbelly - 576 deleted', "Austin's Pizza", 'Qdoba',
#        'Smoothie King', 'Einstein Bros. Bagels', "Torchy's Tacos",
#        'In-N-Out Burger', 'Jack in the Box', "Denny's", 'Magic Wok',
#        'Little Caesars Pizza', 'Mod Pizza',
# ...

# %%
food_types[food_types.name.isin(["Blaze Pizza", "Gatti's Pizza", "Pizza Hut", "Domino's", "Papa John's", "Austin's Pizza", 
                                 "Litte Caesars Pizza", "Mod Pizza", "Red Brick Pizza", "CiCi's Pizza", "Papa Murphy's", "Doubledave's Pizzaworks"])]
# Out:
#      Unnamed: 0  Unnamed: 0.1                     name  \
# 1             1             1              Blaze Pizza
# 17           17            17            Gatti's Pizza
# 35           35            35                Pizza Hut
# 36           36            36              Papa John's
# 41           41            41                 Domino's
# 67           67            67           Austin's Pizza
# 78           78            78                 Domino's
# 87           87            87                 Domino's
# 93           93            93                Mod Pizza
# 104           4             4                 Domino's
# 108           8             8                Pizza Hut
# 114          14            14                 Domino's
# 123          23            23                Mod Pizza
# 140          40            40              Blaze Pizza
# 147          47            47                Pizza Hut
# 148          48            48            Gatti's Pizza
# ...

# %%
food_types[food_types.name.isin(["The Capital Grille", "Uncle Julio's", "Wendy's","Hooters", "Whataburger", "TCBY", "Schlotzky's",
                                "Chick-fil-A", "In-N-Out Burger", "Jack in the Box", "Sonic", "Burger King", "Chili's", "Five Guys", "Arby's"])]
# Out:
#      Unnamed: 0  Unnamed: 0.1                name                  brand_id  \
# 3             3             3  The Capital Grille  569eb7064c054b485d362578
# 5             5             5       Uncle Julio's  57ab44445cc70a501c84a007
# 21           21            21             Wendy's  513fbc1283aa2dc80c00000f
# 22           22            22             Wendy's  513fbc1283aa2dc80c00000f
# 25           25            25             Hooters  57f6a1d7541f3ad614b27e63
# ..          ...           ...                 ...                       ...
# 373          73            73           Five Guys  513fbc1283aa2dc80c00003f
# 381          81            81         Whataburger  513fbc1283aa2dc80c00002f
# 387          87            87             Wendy's  513fbc1283aa2dc80c00000f
# 393          93            93             Wendy's  513fbc1283aa2dc80c00000f
# 396          96            96         Chick-fil-A  513fbc1283aa2dc80c000025
#
# ...
