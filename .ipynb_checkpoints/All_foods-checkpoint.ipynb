# %%
#dependencies 
import pandas as pd

# %%
pizza_csv = "pizza.csv"
burger_csv = "hamburgers.csv"
salads_csv = "salad.csv"
sandwiches_csv = "sandwiches.csv"
smoothies_csv = "smoothies.csv"
burritos_csv = "burritos.csv"

# %%
pizza_df = pd.read_csv(pizza_csv)
burger_df = pd.read_csv(burger_csv)
salads_df = pd.read_csv(salads_csv)
sandwhiches_df = pd.read_csv(sandwiches_csv)
smoothies_df = pd.read_csv(smoothies_csv)
burritos_df = pd.read_csv(burritos_csv)

# %%
burritos_df.head()
# Out:
#    Unnamed: 0    Restaurant               Food_Name  \
# 0           0  Schlotzsky's      Ham Burrito, Whole
# 1           1  Schlotzsky's       Ham Burrito, Half
# 2           2  Schlotzsky's   Sausage Burrito, Half
# 3           3  Schlotzsky's  Sausage Burrito, Whole
# 4           4  Schlotzsky's     Bacon Burrito, Half
#
#                                            Nutrients  Calories
# 0  [{'value': 29, 'attr_id': 203}, {'value': 21, ...       490
# 1  [{'value': 14, 'attr_id': 203}, {'value': 11, ...       240
# 2  [{'value': 15, 'attr_id': 203}, {'value': 15, ...       280
# 3  [{'value': 29, 'attr_id': 203}, {'value': 31, ...       570
# 4  [{'value': 11, 'attr_id': 203}, {'value': 11, ...       230

# %%
#combined pizza and burger DataFrames to be pizza_burger_df
pizza_burger_df = pizza_df.append(burger_df, sort=False)
pizza_burger_df
# Out:
#      Unnamed: 0   Restaurant                     Food_Name  \
# 0             0       Subway                  Cheese Pizza
# 1             1       Subway                 Sausage Pizza
# 2             2       Subway                Meatball Pizza
# 3             3       Subway               Pepperoni Pizza
# 4             4       Subway                   Bacon Pizza
# ..          ...          ...                           ...
# 304         304  Shake Shack           Link Burger, Triple
# 305         305  Shake Shack          Lockhart Link Burger
# 306         306  Shake Shack        Roadside Double Burger
# 307         307  Shake Shack  Lockhart Link Burger, Triple
# 308         308  Shake Shack  Lockhart Link Burger, Double
#
#                                              Nutrients  Calories
# 0    [{'value': 28, 'attr_id': 203}, {'value': 23, ...       720
# 1    [{'value': 35, 'attr_id': 203}, {'value': 35, ...       860
# ...

# %%
#combined pizza_burger_df and salads DataFrames to be pizzburg_salads_df
pizzburg_salads_df =  pizza_burger_df.append(salads_df, sort=False)
pizzburg_salads_df
# Out:
#       Unnamed: 0   Restaurant                     Food_Name  \
# 0              0       Subway                  Cheese Pizza
# 1              1       Subway                 Sausage Pizza
# 2              2       Subway                Meatball Pizza
# 3              3       Subway               Pepperoni Pizza
# 4              4       Subway                   Bacon Pizza
# ...          ...          ...                           ...
# 1104        1104     Fazoli's            Side Chopped Salad
# 1105        1105     Fazoli's           Caesar Italia Salad
# 1106        1106     Fazoli's     Cherry Apple Almond Salad
# 1107        1107     Fazoli's  Fazoli's Italian House Salad
# 1108        1108  Smashburger      Side Salad (No dressing)
#
#                                               Nutrients  Calories
# 0     [{'value': 28, 'attr_id': 203}, {'value': 23, ...       720
# 1     [{'value': 35, 'attr_id': 203}, {'value': 35, ...       860
# ...

# %%
#combined pizzburg_salads_df and sandwhiches_df DataFrames to be pbss_df
pbss_df = pizzburg_salads_df.append(sandwhiches_df, sort=False)
pbss_df
# Out:
#      Unnamed: 0       Restaurant  \
# 0             0           Subway
# 1             1           Subway
# 2             2           Subway
# 3             3           Subway
# 4             4           Subway
# ..          ...              ...
# 597         597  Johnny Carino's
# 598         598  Johnny Carino's
# 599         599  Johnny Carino's
# 600         600  Johnny Carino's
# 601         601  Johnny Carino's
#
#                                              Food_Name  \
# 0                                         Cheese Pizza
# 1                                        Sausage Pizza
# 2                                       Meatball Pizza
# 3                                      Pepperoni Pizza
# 4                                          Bacon Pizza
# ..                                                 ...
# 597                Meatball Sandwich with Tomato Sauce
# 598               Sausage Sandwich with Parmesan Fries
# 599                 Sausage Sandwich with Tomato Sauce
# ...

# %%
#pbss_df and smoothies_df DataFrames to be pbss_smoothies_df
pbss_smoothies_df = pbss_df.append(smoothies_df, sort=False)
pbss_smoothies_df
# Out:
#      Unnamed: 0              Restaurant                            Food_Name  \
# 0             0                  Subway                         Cheese Pizza
# 1             1                  Subway                        Sausage Pizza
# 2             2                  Subway                       Meatball Pizza
# 3             3                  Subway                      Pepperoni Pizza
# 4             4                  Subway                          Bacon Pizza
# ..          ...                     ...                                  ...
# 171         171  Frullati Cafe & Bakery        Banana Banana Smoothie, Small
# 172         172  Frullati Cafe & Bakery     Blueberry Banana Smoothie, Large
# 173         173  Frullati Cafe & Bakery  Blueberry Pineapple Smoothie, Large
# 174         174  Frullati Cafe & Bakery     Chocolate Banana Smoothie, Large
# 175         175  Frullati Cafe & Bakery           Mocha Java Smoothie, Large
#
# ...

# %%
#pbss_smoothies_df and burritos_df DataFrames to be all_food_df
all_food_df = pbss_smoothies_df.append(burritos_df, sort=False)
all_food_df
# Out:
#      Unnamed: 0                    Restaurant  \
# 0             0                        Subway
# 1             1                        Subway
# 2             2                        Subway
# 3             3                        Subway
# 4             4                        Subway
# ..          ...                           ...
# 146         146  La Salsa Fresh Mexican Grill
# 147         147  La Salsa Fresh Mexican Grill
# 148         148  La Salsa Fresh Mexican Grill
# 149         149  La Salsa Fresh Mexican Grill
# 150         150  La Salsa Fresh Mexican Grill
#
#                                   Food_Name  \
# 0                              Cheese Pizza
# 1                             Sausage Pizza
# 2                            Meatball Pizza
# 3                           Pepperoni Pizza
# 4                               Bacon Pizza
# ..                                      ...
# 146      Overstuffed Grilled Burrito, Steak
# 147              Side of Chips for Burritos
# ...

# %%
all_food_df = all_food_df.drop(columns="Unnamed: 0")
all_food_df
# Out:
#                        Restaurant                               Food_Name  \
# 0                          Subway                            Cheese Pizza
# 1                          Subway                           Sausage Pizza
# 2                          Subway                          Meatball Pizza
# 3                          Subway                         Pepperoni Pizza
# 4                          Subway                             Bacon Pizza
# ..                            ...                                     ...
# 146  La Salsa Fresh Mexican Grill      Overstuffed Grilled Burrito, Steak
# 147  La Salsa Fresh Mexican Grill              Side of Chips for Burritos
# 148  La Salsa Fresh Mexican Grill     California Burrito with Pinto Beans
# 149  La Salsa Fresh Mexican Grill     California Burrito with Black Beans
# 150  La Salsa Fresh Mexican Grill  Bean & Cheese Burrito with Black Beans
#
#                                              Nutrients  Calories
# ...

# %%
# Export file as a CSV, without the Pandas index, but with the header
all_food_df.to_csv("output/all_food.csv", index=False, header=True)
