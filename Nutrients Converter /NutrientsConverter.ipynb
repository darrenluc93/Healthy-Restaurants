# %%
import pandas as pd

import ast

# %%
foodRaw_df = pd.read_csv('pizza.csv')

foodRaw_df.head()
# Out:
#    Unnamed: 0 Restaurant        Food_Name  \
# 0           0     Subway     Cheese Pizza
# 1           1     Subway    Sausage Pizza
# 2           2     Subway   Meatball Pizza
# 3           3     Subway  Pepperoni Pizza
# 4           4     Subway      Bacon Pizza
#
#                                            Nutrients  Calories
# 0  [{'value': 28, 'attr_id': 203}, {'value': 23, ...       720
# 1  [{'value': 35, 'attr_id': 203}, {'value': 35, ...       860
# 2  [{'value': 37, 'attr_id': 203}, {'value': 33, ...       860
# 3  [{'value': 35, 'attr_id': 203}, {'value': 33, ...       840
# 4  [{'value': 37, 'attr_id': 203}, {'value': 31, ...       840

# %%
nutrient_map = pd.read_csv('Nutritionix API v2 - Full Nutrient USDA Field Mapping.csv')

nutrient_map = nutrient_map.set_index('attr_id')

nutrient_map.head()
# Out:
#          2018 NFP    usda_tag                         name  unit notes  \
# attr_id
# 203           1.0      PROCNT                      Protein     g   NaN
# 204           1.0         FAT            Total lipid (fat)     g   NaN
# 205           1.0      CHOCDF  Carbohydrate, by difference     g   NaN
# 207           0.0         ASH                          Ash     g   NaN
# 208           1.0  ENERC_KCAL                       Energy  kcal   NaN
#
#                 bulk_csv_field cxh_attribute_name Unnamed: 8
# attr_id
# 203                 nf_protein               PRO-        NaN
# 204               nf_total_fat                FAT        NaN
# 205      nf_total_carbohydrate               CHO-        NaN
# 207                        NaN                NaN        NaN
# 208                nf_calories              ENER-        NaN

# %%
for index,row in foodRaw_df.iterrows(): #iterate each index and row.
    
    nutrients = ast.literal_eval(row['Nutrients']) #The original column was as string. ast.literal_eval -->interprets "strings, bytes, numbers, tuples, lists, dicts, sets, booleans, and None." and returns it in the right format.. Anything else is an error.
    
    for nutrient in nutrients: #Iterates each of the nutrients dictionaries. 
        
        name = nutrient_map.loc[nutrient['attr_id'],'name'] #locates the name in the nutrient_map csv. 
        value = nutrient['value'] 
        
        if name in foodRaw_df.columns: #if the nutrient is a DataFrame column.
                
            foodRaw_df.loc[index,name] = value #Adds the value. 
        
        else: #if the nutrient is not in the DataFrame
            foodRaw_df[name] =''
            foodRaw_df.loc[index,name] = value
        
food_df = foodRaw_df.replace(r"^\s*$", 0, regex = True) #Finds and replace empty cells with 0. empty cell pattern = r"^\s*$"

food_df
# Out:
#      Unnamed: 0     Restaurant                           Food_Name  \
# 0             0         Subway                        Cheese Pizza
# 1             1         Subway                       Sausage Pizza
# 2             2         Subway                      Meatball Pizza
# 3             3         Subway                     Pepperoni Pizza
# 4             4         Subway                         Bacon Pizza
# ..          ...            ...                                 ...
# 435         435  Extreme Pizza       Holy Cow! Pizza, Huge 18 inch
# 436         436  Extreme Pizza        Paia Pie Pizza, Huge 18 inch
# 437         437  Extreme Pizza  Pandora's Box Pizza, Large 14 inch
# 438         438       Fazoli's                  Cheese Pizza Slice
# 439         439       Fazoli's               Pepperoni Pizza Slice
#
#                                              Nutrients  Calories  Protein  \
# 0    [{'value': 28, 'attr_id': 203}, {'value': 23, ...       720       28
# 1    [{'value': 35, 'attr_id': 203}, {'value': 35, ...       860       35
# 2    [{'value': 37, 'attr_id': 203}, {'value': 33, ...       860       37
# 3    [{'value': 35, 'attr_id': 203}, {'value': 33, ...       840       35
# 4    [{'value': 37, 'attr_id': 203}, {'value': 31, ...       840       37
# ..                                                 ...       ...      ...
# 435  [{'value': 49, 'attr_id': 205}, {'value': 510,...       510        0
# 436  [{'value': 59, 'attr_id': 205}, {'value': 430,...       430        0
# 437  [{'value': 38, 'attr_id': 205}, {'value': 270,...       270        0
# 438  [{'value': 15, 'attr_id': 203}, {'value': 14, ...       310       15
# 439  [{'value': 14, 'attr_id': 203}, {'value': 15, ...       320       14
#
#      Total lipid (fat)  Carbohydrate, by difference  Energy  Sugars, total  \
# 0                 23.0                           97     720              7
# 1                 35.0                           98     860              8
# 2                 33.0                          100     860              7
# 3                 33.0                           97     840              8
# 4                 31.0                           98     840              8
# ..                 ...                          ...     ...            ...
# 435                0.0                           49     510              0
# 436                0.0                           59     430              0
# 437                0.0                           38     270              0
# 438               14.0                           32     310              3
# 439               15.0                           32     320              3
#
#      Fiber, total dietary  Calcium, Ca  Iron, Fe  Sodium, Na  Vitamin A, IU  \
# 0                       4          520       7.2        1530           1000
# 1                       4          650       7.2        1870           1000
# 2                       5          650       8.1        1840           1000
# 3                       4          650       7.2        1800           1000
# 4                       4          650       7.2        2060           1000
# ..                    ...          ...       ...         ...            ...
# 435                     0            0       0.0         710              0
# 436                     0            0       0.0         830              0
# 437                     0            0       0.0         610              0
# 438                     2          325       2.7         620              0
# 439                     2          260       2.7         720              0
#
#      Vitamin C, total ascorbic acid  Cholesterol  Fatty acids, total trans  \
# 0                               9.0           50                       0.5
# 1                               9.0           80                       0.5
# 2                               9.0           80                       1.0
# 3                               9.0           70                       1.0
# 4                               9.0           70                       0.5
# ..                              ...          ...                       ...
# 435                             0.0            0                       0.0
# 436                             0.0            0                       0.0
# 437                             0.0            0                       0.0
# 438                             3.6           30                       0.5
# 439                             3.6           30                       0.5
#
#      Fatty acids, total saturated
# 0                             9.0
# 1                            14.0
# 2                            14.0
# 3                            13.0
# 4                            12.0
# ..                            ...
# 435                          11.0
# 436                           8.0
# 437                           4.5
# 438                           7.0
# 439                           7.0
#
# [440 rows x 19 columns]
