# %%
import pandas as pd

import ast

# %%
foodRaw_df = pd.read_csv('smoothies.csv')

foodRaw_df.head()
# Out:
#    Unnamed: 0     Restaurant                      Food_Name  \
# 0           0  Auntie Anne's       Mango Smoothie, 32 fl oz
# 1           1  Auntie Anne's  Strawberry Smoothie, 16 fl oz
# 2           2  Auntie Anne's  Strawberry Smoothie, 20 fl oz
# 3           3  Auntie Anne's       Mango Smoothie, 16 fl oz
# 4           4  Auntie Anne's  Strawberry Smoothie, 32 fl oz
#
#                                            Nutrients  Calories
# 0  [{'value': 1, 'attr_id': 203}, {'value': 0, 'a...       470
# 1  [{'value': 1, 'attr_id': 203}, {'value': 0, 'a...       220
# 2  [{'value': 1, 'attr_id': 203}, {'value': 0, 'a...       290
# 3  [{'value': 0, 'attr_id': 203}, {'value': 0, 'a...       230
# 4  [{'value': 1, 'attr_id': 203}, {'value': 0, 'a...       440

# %%
nutrient_map = pd.read_csv('Nutritionix API v2 - Full Nutrient USDA Field Mapping.csv')

nutrient_map = nutrient_map.set_index('attr_id')

nutrient_map.head()
# Out:
#          2018 NFP    usda_tag                         name  unit notes  \
# attr_id
# 203           1.0      PROCNT                      Protein     g   NaN
# 204           1.0         FAT            Total lipid (fat)     g   NaN
# 205           1.0      CHOCDF  Carbohydrate, by difference     g   NaN
# 207           0.0         ASH                          Ash     g   NaN
# 208           1.0  ENERC_KCAL                       Energy  kcal   NaN
#
#                 bulk_csv_field cxh_attribute_name Unnamed: 8
# attr_id
# 203                 nf_protein               PRO-        NaN
# 204               nf_total_fat                FAT        NaN
# 205      nf_total_carbohydrate               CHO-        NaN
# 207                        NaN                NaN        NaN
# 208                nf_calories              ENER-        NaN

# %%
for index,row in foodRaw_df.iterrows(): #iterate each index and row.
    
    nutrients = ast.literal_eval(row['Nutrients']) #The original column was as string. ast.literal_eval -->interprets "strings, bytes, numbers, tuples, lists, dicts, sets, booleans, and None." and returns it in the right format.. Anything else is an error.
    
    for nutrient in nutrients: #Iterates each of the nutrients dictionaries. 
        
        name = nutrient_map.loc[nutrient['attr_id'],'name'] #locates the name in the nutrient_map csv. 
        value = nutrient['value'] 
        
        
        if name in foodRaw_df.columns: #if the nutrient is a DataFrame column.   
            foodRaw_df.loc[index,name] = value  #Adds the value and unit.
        
        else: #if the nutrient is not in the DataFrame
            foodRaw_df[name] =''
            foodRaw_df.loc[index,name] = value
        
food_df = foodRaw_df.replace(r"^\s*$", 0, regex = True) #Finds and replace empty cells with 0. empty cell pattern = r"^\s*$"
food_df.reset_index(drop=True)
food_df.drop('Unnamed: 0', axis=1, inplace=True)
food_df = food_df.loc[food_df['Restaurant']== 'Smoothie King'] #Select restaurant


food_df.head(50)
# Out:
#         Restaurant                    Food_Name  \
# 97   Smoothie King           Gladiator Smoothie
# 98   Smoothie King           MangoFest Smoothie
# 99   Smoothie King    Blueberry Heaven Smoothie
# 100  Smoothie King       Caribbean Way Smoothie
# 101  Smoothie King        Fruit Fusion Smoothie
# 102  Smoothie King  Mangosteen Madness Smoothie
# 103  Smoothie King      Acai Adventure Smoothie
# 104  Smoothie King       Island Impact Smoothie
# 105  Smoothie King      Pineapple Surf Smoothie
# 106  Smoothie King  Raspberry Collider Smoothie
# 107  Smoothie King          Angel Food Smoothie
# 108  Smoothie King      Immune Builder Smoothie
# 109  Smoothie King     Lean1 Chocolate Smoothie
# 110  Smoothie King  Pineapple Pleasure Smoothie
# 111  Smoothie King         Banana Boat Smoothie
# 112  Smoothie King    Lean1 Strawberry Smoothie
# 113  Smoothie King    Passion Passport Smoothie
# 114  Smoothie King         Berry Punch Smoothie
# 115  Smoothie King        Hearty Apple Smoothie
# 116  Smoothie King       Lean1 Vanilla Smoothie
#
#                                              Nutrients  Calories  Protein  \
# 97   [{'value': 45, 'attr_id': 203}, {'value': 0, '...       180  [45, g]
# 98   [{'value': 0, 'attr_id': 203}, {'value': 0, 'a...       290   [0, g]
# 99   [{'value': 7, 'attr_id': 203}, {'value': 1, 'a...       330   [7, g]
# 100  [{'value': 1, 'attr_id': 203}, {'value': 0, 'a...       400   [1, g]
# 101  [{'value': 9, 'attr_id': 203}, {'value': 1, 'a...       360   [9, g]
# 102  [{'value': 1, 'attr_id': 203}, {'value': 0, 'a...       380   [1, g]
# 103  [{'value': 5, 'attr_id': 203}, {'value': 5, 'a...       440   [5, g]
# 104  [{'value': 3, 'attr_id': 203}, {'value': 1, 'a...       310   [3, g]
# 105  [{'value': 7, 'attr_id': 203}, {'value': 1, 'a...       460   [7, g]
# 106  [{'value': 1, 'attr_id': 203}, {'value': 0, 'a...       340   [1, g]
# 107  [{'value': 4, 'attr_id': 203}, {'value': 0, 'a...       350   [4, g]
# 108  [{'value': 5, 'attr_id': 203}, {'value': 1, 'a...       380   [5, g]
# 109  [{'value': 22, 'attr_id': 203}, {'value': 11, ...       290  [22, g]
# 110  [{'value': 1, 'attr_id': 203}, {'value': 0, 'a...       280   [1, g]
# 111  [{'value': 12, 'attr_id': 203}, {'value': 4, '...       480  [12, g]
# 112  [{'value': 20, 'attr_id': 203}, {'value': 6, '...       280  [20, g]
# 113  [{'value': 1, 'attr_id': 203}, {'value': 0, 'a...       400   [1, g]
# 114  [{'value': 0, 'attr_id': 203}, {'value': 0, 'a...       360   [0, g]
# 115  [{'value': 9, 'attr_id': 203}, {'value': 1, 'a...       410   [9, g]
# 116  [{'value': 22, 'attr_id': 203}, {'value': 10, ...       270  [22, g]
#
#     Total lipid (fat) Carbohydrate, by difference    Energy Sugars, total  \
# 97             [0, g]                      [1, g]  [180, g]        [0, g]
# 98             [0, g]                     [72, g]  [290, g]       [59, g]
# 99             [1, g]                     [73, g]  [330, g]       [64, g]
# 100            [0, g]                     [97, g]  [400, g]       [89, g]
# 101            [1, g]                     [76, g]  [360, g]       [66, g]
# 102            [0, g]                     [94, g]  [380, g]       [92, g]
# 103            [5, g]                     [92, g]  [440, g]       [75, g]
# 104            [1, g]                     [73, g]  [310, g]       [65, g]
# 105            [1, g]                    [104, g]  [460, g]       [92, g]
# 106            [0, g]                     [86, g]  [340, g]       [74, g]
# 107            [0, g]                     [84, g]  [350, g]       [75, g]
# 108            [1, g]                     [89, g]  [380, g]       [77, g]
# 109           [11, g]                     [28, g]  [290, g]       [18, g]
# 110            [0, g]                     [67, g]  [280, g]       [62, g]
# 111            [4, g]                    [101, g]  [480, g]       [77, g]
# 112            [6, g]                     [35, g]  [280, g]       [28, g]
# 113            [0, g]                     [96, g]  [400, g]       [93, g]
# 114            [0, g]                     [91, g]  [360, g]       [84, g]
# 115            [1, g]                     [86, g]  [410, g]       [75, g]
# 116           [10, g]                     [26, g]  [270, g]       [17, g]
#
#     Fiber, total dietary Calcium, Ca Iron, Fe Sodium, Na Vitamin A, IU  \
# 97                [0, g]           0        0   [150, g]             0
# 98                [1, g]           0        0    [10, g]             0
# 99                [2, g]           0        0   [260, g]             0
# 100               [6, g]           0        0     [0, g]             0
# 101               [0, g]           0        0   [300, g]             0
# 102               [2, g]           0        0    [30, g]             0
# 103               [4, g]           0        0   [160, g]             0
# 104               [1, g]           0        0   [140, g]             0
# 105               [4, g]           0        0   [280, g]             0
# 106               [4, g]           0        0   [100, g]             0
# 107               [6, g]           0        0    [50, g]             0
# 108               [6, g]           0        0    [55, g]             0
# 109               [7, g]           0        0   [320, g]             0
# 110               [3, g]           0        0    [25, g]             0
# 111               [3, g]           0        0   [320, g]             0
# 112               [5, g]           0        0   [320, g]             0
# 113               [2, g]           0        0    [15, g]             0
# 114               [4, g]           0        0    [95, g]             0
# 115               [2, g]           0        0   [270, g]             0
# 116               [5, g]           0        0   [320, g]             0
#
#     Vitamin C, total ascorbic acid Cholesterol Fatty acids, total trans  \
# 97                               0      [0, g]                        0
# 98                               0      [0, g]                        0
# 99                               0     [10, g]                        0
# 100                              0      [0, g]                        0
# 101                              0     [10, g]                        0
# 102                              0      [0, g]                        0
# 103                              0      [5, g]                        0
# 104                              0      [5, g]                        0
# 105                              0     [10, g]                        0
# 106                              0      [0, g]                        0
# 107                              0      [0, g]                        0
# 108                              0      [0, g]                        0
# 109                              0      [5, g]                        0
# 110                              0      [0, g]                        0
# 111                              0     [20, g]                        0
# 112                              0      [5, g]                        0
# 113                              0      [0, g]                        0
# 114                              0      [0, g]                        0
# 115                              0     [15, g]                        0
# 116                              0      [5, g]                        0
#
#     Fatty acids, total saturated
# 97                        [0, g]
# 98                        [0, g]
# 99                        [0, g]
# 100                       [0, g]
# 101                       [0, g]
# 102                       [0, g]
# 103                       [1, g]
# 104                       [0, g]
# 105                       [0, g]
# 106                       [0, g]
# 107                       [0, g]
# 108                       [0, g]
# 109                       [1, g]
# 110                       [0, g]
# 111                       [6, g]
# 112                       [1, g]
# 113                       [0, g]
# 114                       [0, g]
# 115                       [0, g]
# 116                       [1, g]
