# %%
import pandas as pd

#Make sure to run the NutrientsConverter in the Jupyter Notebook folder to be able to call the DataFrames Stored. 

#DataFrames with the combine info.
# %store -r maleInfo

# %store -r femaleInfo

# %store -r foodFiltered_df

# %%
maleInfo[2]
# Out:
#     AGE  Active Protein (Cal) Carbohydrate (Cal) Fiber (gr) Total Sugar (gr)  \
# 0    14    2800        186.67             513.33      10.27            13.33
# 1    15    3000           200                550      10.27            13.33
# 2    16    3200        213.33             586.67      10.27            13.33
# 3    17    3200        213.33             586.67      10.27            13.33
# 4    18    3200        213.33             586.67      10.27            13.33
# ..  ...     ...           ...                ...        ...              ...
# 58   72    2600        173.33             476.67      10.27            13.33
# 59   73    2600        173.33             476.67      10.27            13.33
# 60   74    2600        173.33             476.67      10.27            13.33
# 61   75    2600        173.33             476.67      10.27            13.33
# 62   76    2400           160                440      10.27            13.33
#
#    Total lipid (Cal) Total Trans Fat (Cal) Total Saturated Fat (Cal)  \
# 0                280                  9.33                     93.33
# 1                300                    10                       100
# 2                320                 10.67                    106.67
# 3                320                 10.67                    106.67
# 4                320                 10.67                    106.67
# ..               ...                   ...                       ...
# 58               260                  8.67                     86.67
# 59               260                  8.67                     86.67
# 60               260                  8.67                     86.67
# 61               260                  8.67                     86.67
# 62               240                     8                        80
#
#    Cholesterol (mg) Calcium (mg) Iron (mg) Sodium, (mg) Vitamin A (mcg RAE)  \
# 0             83.33       433.33       5.5       766.67                 300
# 1             83.33       433.33       5.5       766.67                 300
# 2             83.33       433.33       5.5       766.67                 300
# 3             83.33       433.33       5.5       766.67                 300
# 4             83.33       433.33       5.5       766.67                 300
# ..              ...          ...       ...          ...                 ...
# 58            83.33       433.33       5.5       766.67                 300
# 59            83.33       433.33       5.5       766.67                 300
# 60            83.33       433.33       5.5       766.67                 300
# 61            83.33       433.33       5.5       766.67                 300
# 62            83.33       433.33       5.5       766.67                 300
#
#    Vitamin C (mg)
# 0              25
# 1              25
# 2              25
# 3              25
# 4              25
# ..            ...
# 58             25
# 59             25
# 60             25
# 61             25
# 62             25
#
# [63 rows x 15 columns]

# %%
Nutrients = ['Protein (Cal)',
             'Carbohydrate (Cal)', 
             'Fiber (gr)',
             'Total Sugar (gr)', 
             'Total lipid (Cal)', 
             'Total Trans Fat (Cal)',
             'Total Saturated Fat (Cal)',
             'Cholesterol (mg)', 
             'Calcium (mg)',
             'Iron (mg)', 
             'Sodium, (mg)', 
             'Vitamin A (mcg RAE)', 
             'Vitamin C (mg)']

for i in range(len(maleInfo)):
    
    analysis_df = maleInfo[i]
    
    analysis_df['Restaurant Points'] = ""
    
    for index, row in analysis_df.iterrows():
        
        restaurantTally_dict = {}
        
        for food in range(len(foodFiltered_df)):
            
            if foodFiltered_df.loc[food,'Restaurant'] not in restaurantTally_dict.keys():
                restaurantTally_dict[foodFiltered_df.loc[food,'Restaurant']] = 0
                
            if (foodFiltered_df.loc[food,'Protein (Cal)'] <= row['Protein (Cal)']) :
                restaurantTally_dict[foodFiltered_df.loc[food,'Restaurant']] += 1

            if (foodFiltered_df.loc[food,'Carbohydrate (Cal)'] <= row['Carbohydrate (Cal)']):
                restaurantTally_dict[foodFiltered_df.loc[food,'Restaurant']] += 1

            if (foodFiltered_df.loc[food,'Fiber (gr)'] <= row['Fiber (gr)']):
                restaurantTally_dict[foodFiltered_df.loc[food,'Restaurant']] += 1

            if (foodFiltered_df.loc[food,'Total Sugar (gr)'] <= row['Total Sugar (gr)']):
                restaurantTally_dict[foodFiltered_df.loc[food,'Restaurant']] += 1

            if (foodFiltered_df.loc[food,'Total Fat (Cal)'] <= row['Total lipid (Cal)']):
                restaurantTally_dict[foodFiltered_df.loc[food,'Restaurant']] += 1

            if (foodFiltered_df.loc[food,'Total Trans Fat (Cal)'] <= row['Total Trans Fat (Cal)']):
                restaurantTally_dict[foodFiltered_df.loc[food,'Restaurant']] += 1

            if (foodFiltered_df.loc[food,'Total Saturated Fat (Cal)'] <= row['Total Saturated Fat (Cal)']):
                restaurantTally_dict[foodFiltered_df.loc[food,'Restaurant']] += 1

            if (foodFiltered_df.loc[food,'Cholesterol (mg)'] <= row['Cholesterol (mg)']):
                restaurantTally_dict[foodFiltered_df.loc[food,'Restaurant']] += 1

            if (foodFiltered_df.loc[food,'Calcium (mg)'] <= row['Calcium (mg)']):
                restaurantTally_dict[foodFiltered_df.loc[food,'Restaurant']] += 1

            if (foodFiltered_df.loc[food,'Iron (mg)'] <= row['Iron (mg)']):
                restaurantTally_dict[foodFiltered_df.loc[food,'Restaurant']] += 1

            if (foodFiltered_df.loc[food,'Sodium (mg)'] <= row['Sodium, (mg)']):
                restaurantTally_dict[foodFiltered_df.loc[food,'Restaurant']] += 1

            if (foodFiltered_df.loc[food,'Vitamin A (mcg RAE)'] <= row['Vitamin A (mcg RAE)']):
                restaurantTally_dict[foodFiltered_df.loc[food,'Restaurant']] += 1

            if (foodFiltered_df.loc[food,'Vitamin C (mg)'] <= row['Vitamin C (mg)']):
                restaurantTally_dict[foodFiltered_df.loc[food,'Restaurant']] += 1 
                
        row['Restaurant Points'] = restaurantTally_dict
        
    maleInfo[i] = analysis_df

# %%
analysis_df
# Out:
#     AGE  Active Protein (Cal) Carbohydrate (Cal) Fiber (gr) Total Sugar (gr)  \
# 0    14    2800        186.67             513.33      10.27            13.33
# 1    15    3000           200                550      10.27            13.33
# 2    16    3200        213.33             586.67      10.27            13.33
# 3    17    3200        213.33             586.67      10.27            13.33
# 4    18    3200        213.33             586.67      10.27            13.33
# ..  ...     ...           ...                ...        ...              ...
# 58   72    2600        173.33             476.67      10.27            13.33
# 59   73    2600        173.33             476.67      10.27            13.33
# 60   74    2600        173.33             476.67      10.27            13.33
# 61   75    2600        173.33             476.67      10.27            13.33
# 62   76    2400           160                440      10.27            13.33
#
#    Total lipid (Cal) Total Trans Fat (Cal) Total Saturated Fat (Cal)  \
# 0                280                  9.33                     93.33
# 1                300                    10                       100
# 2                320                 10.67                    106.67
# 3                320                 10.67                    106.67
# 4                320                 10.67                    106.67
# ..               ...                   ...                       ...
# 58               260                  8.67                     86.67
# 59               260                  8.67                     86.67
# 60               260                  8.67                     86.67
# 61               260                  8.67                     86.67
# 62               240                     8                        80
#
#    Cholesterol (mg) Calcium (mg) Iron (mg) Sodium, (mg) Vitamin A (mcg RAE)  \
# 0             83.33       433.33       5.5       766.67                 300
# 1             83.33       433.33       5.5       766.67                 300
# 2             83.33       433.33       5.5       766.67                 300
# 3             83.33       433.33       5.5       766.67                 300
# 4             83.33       433.33       5.5       766.67                 300
# ..              ...          ...       ...          ...                 ...
# 58            83.33       433.33       5.5       766.67                 300
# 59            83.33       433.33       5.5       766.67                 300
# 60            83.33       433.33       5.5       766.67                 300
# 61            83.33       433.33       5.5       766.67                 300
# 62            83.33       433.33       5.5       766.67                 300
#
#    Vitamin C (mg) Restaurant Points
# 0              25
# 1              25
# 2              25
# 3              25
# 4              25
# ..            ...               ...
# 58             25
# 59             25
# 60             25
# 61             25
# 62             25
#
# [63 rows x 16 columns]

# %%
maleInfo[1]
# Out:
#     AGE  Moderately active Protein (Cal) Carbohydrate (Cal) Fiber (gr)  \
# 0    14               2400           160                440      10.27
# 1    15               2600        173.33             476.67      10.27
# 2    16               2800        186.67             513.33      10.27
# 3    17               2800        186.67             513.33      10.27
# 4    18               2800        186.67             513.33      10.27
# ..  ...                ...           ...                ...        ...
# 58   72               2200        146.67             403.33      10.27
# 59   73               2200        146.67             403.33      10.27
# 60   74               2200        146.67             403.33      10.27
# 61   75               2200        146.67             403.33      10.27
# 62   76               2200        146.67             403.33      10.27
#
#    Total Sugar (gr) Total lipid (Cal) Total Trans Fat (Cal)  \
# 0             13.33               240                     8
# 1             13.33               260                  8.67
# 2             13.33               280                  9.33
# 3             13.33               280                  9.33
# 4             13.33               280                  9.33
# ..              ...               ...                   ...
# 58            13.33               220                  7.33
# 59            13.33               220                  7.33
# 60            13.33               220                  7.33
# 61            13.33               220                  7.33
# 62            13.33               220                  7.33
#
#    Total Saturated Fat (Cal) Cholesterol (mg) Calcium (mg) Iron (mg)  \
# 0                         80            83.33       433.33       5.5
# 1                      86.67            83.33       433.33       5.5
# 2                      93.33            83.33       433.33       5.5
# 3                      93.33            83.33       433.33       5.5
# 4                      93.33            83.33       433.33       5.5
# ..                       ...              ...          ...       ...
# 58                     73.33            83.33       433.33       5.5
# 59                     73.33            83.33       433.33       5.5
# 60                     73.33            83.33       433.33       5.5
# 61                     73.33            83.33       433.33       5.5
# 62                     73.33            83.33       433.33       5.5
#
#    Sodium, (mg) Vitamin A (mcg RAE) Vitamin C (mg) Restaurant Points
# 0        766.67                 300             25
# 1        766.67                 300             25
# 2        766.67                 300             25
# 3        766.67                 300             25
# 4        766.67                 300             25
# ..          ...                 ...            ...               ...
# 58       766.67                 300             25
# 59       766.67                 300             25
# 60       766.67                 300             25
# 61       766.67                 300             25
# 62       766.67                 300             25
#
# [63 rows x 16 columns]
