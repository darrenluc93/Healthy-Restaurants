# %%
#dependencies
import pandas as pd

# %%
all_food_csv = "Resources/all_food.csv"
all_food_df = pd.read_csv(all_food_csv)
all_food_df
# Out:
#                         Restaurant                               Food_Name  \
# 0                           Subway                            Cheese Pizza
# 1                           Subway                           Sausage Pizza
# 2                           Subway                          Meatball Pizza
# 3                           Subway                         Pepperoni Pizza
# 4                           Subway                             Bacon Pizza
# ...                            ...                                     ...
# 2782  La Salsa Fresh Mexican Grill      Overstuffed Grilled Burrito, Steak
# 2783  La Salsa Fresh Mexican Grill              Side of Chips for Burritos
# 2784  La Salsa Fresh Mexican Grill     California Burrito with Pinto Beans
# 2785  La Salsa Fresh Mexican Grill     California Burrito with Black Beans
# 2786  La Salsa Fresh Mexican Grill  Bean & Cheese Burrito with Black Beans
#
#                                               Nutrients  Calories
# 0     [{'value': 28, 'attr_id': 203}, {'value': 23, ...       720
# 1     [{'value': 35, 'attr_id': 203}, {'value': 35, ...       860
# 2     [{'value': 37, 'attr_id': 203}, {'value': 33, ...       860
# 3     [{'value': 35, 'attr_id': 203}, {'value': 33, ...       840
# 4     [{'value': 37, 'attr_id': 203}, {'value': 31, ...       840
# ...                                                 ...       ...
# 2782  [{'value': 66, 'attr_id': 203}, {'value': 66, ...      1290
# 2783  [{'value': 3, 'attr_id': 203}, {'value': 10, '...       200
# 2784  [{'value': 27, 'attr_id': 203}, {'value': 29, ...       690
# 2785  [{'value': 28, 'attr_id': 203}, {'value': 29, ...       710
# 2786  [{'value': 48, 'attr_id': 203}, {'value': 48, ...      1100
#
# [2787 rows x 4 columns]

# %%
#getting paneras menu items out of all_food_df
#set restaurant as index
panerabread_df = all_food_df.set_index('Restaurant')
#located needed restaurant
panerabread_df = panerabread_df.loc[["Panera Bread"]]
#set index to food name
panerabread_df = panerabread_df.set_index("Food_Name")
#search for 7 items we need
panerabread_df = panerabread_df.loc[["Caesar Salad with Chicken, Whole",
                                     "Mediterranean Veggie Sandwich on Tomato Basil, Whole",
                                     "Napa Almond Chicken Salad Sandwich on Country Rustic, Whole",
                                     "Fuji Apple Salad with Chicken, Whole",
                                    "Modern Greek Salad with Quinoa, Whole",
                                    "Bacon Turkey Bravo Sandwich on Tomato Basil, Whole",
                                    "Green Passion Smoothie"]]
#put 7 items into dataframe and reset index
panerabread_items_df = panerabread_df.reset_index()
#added restaurant column back
panerabread_items_df['Restaurant'] = 'Panera Bread'
#set the index back to restaurant
panerabread_items_df = panerabread_items_df.set_index("Restaurant")
panerabread_items_df
# Out:
#                                                       Food_Name  \
# Restaurant
# Panera Bread                   Caesar Salad with Chicken, Whole
# Panera Bread  Mediterranean Veggie Sandwich on Tomato Basil,...
# Panera Bread  Napa Almond Chicken Salad Sandwich on Country ...
# Panera Bread               Fuji Apple Salad with Chicken, Whole
# Panera Bread              Modern Greek Salad with Quinoa, Whole
# Panera Bread  Bacon Turkey Bravo Sandwich on Tomato Basil, W...
# Panera Bread                             Green Passion Smoothie
#
#                                                       Nutrients  Calories
# Restaurant
# Panera Bread  [{'value': 35, 'attr_id': 203}, {'value': 27, ...       450
# Panera Bread  [{'value': 18, 'attr_id': 203}, {'value': 13, ...       440
# Panera Bread  [{'value': 28, 'attr_id': 203}, {'value': 32, ...       630
# Panera Bread  [{'value': 33, 'attr_id': 203}, {'value': 35, ...       570
# Panera Bread  [{'value': 12, 'attr_id': 203}, {'value': 43, ...       530
# Panera Bread  [{'value': 46, 'attr_id': 203}, {'value': 24, ...       630
# Panera Bread  [{'value': 2, 'attr_id': 203}, {'value': 0, 'a...       200

# %%
#getting restaurant items out of all_food_df
#set restaurant as index
smoothie_king_df = all_food_df.set_index('Restaurant')
#located needed restaurant
smoothie_king_df = smoothie_king_df.loc[["Smoothie King"]]
#set index to food name
smoothie_king_df = smoothie_king_df.set_index("Food_Name")
#search for 7 items we need
smoothie_king_df = smoothie_king_df.loc[["Lean1 Chocolate Smoothie",
                                     "Gladiator Smoothie",
                                     "Lean1 Strawberry Smoothie",
                                     "Berry Punch Smoothie",
                                    "Lean1 Vanilla Smoothie",
                                    "Immune Builder Smoothie",
                                    "Blueberry Heaven Smoothie"]]
#put 7 items into dataframe and reset index
smoothie_king_items_df = smoothie_king_df.reset_index()
#added restaurant column back
smoothie_king_items_df["Restaurant"] = 'Smoothie King'
#set the index back to restaurant
smoothie_king_items_df = smoothie_king_items_df.set_index("Restaurant")
smoothie_king_items_df
# Out:
#                                Food_Name  \
# Restaurant
# Smoothie King   Lean1 Chocolate Smoothie
# Smoothie King         Gladiator Smoothie
# Smoothie King  Lean1 Strawberry Smoothie
# Smoothie King       Berry Punch Smoothie
# Smoothie King     Lean1 Vanilla Smoothie
# Smoothie King    Immune Builder Smoothie
# Smoothie King  Blueberry Heaven Smoothie
#
#                                                        Nutrients  Calories
# Restaurant
# Smoothie King  [{'value': 22, 'attr_id': 203}, {'value': 11, ...       290
# Smoothie King  [{'value': 45, 'attr_id': 203}, {'value': 0, '...       180
# Smoothie King  [{'value': 20, 'attr_id': 203}, {'value': 6, '...       280
# Smoothie King  [{'value': 0, 'attr_id': 203}, {'value': 0, 'a...       360
# Smoothie King  [{'value': 22, 'attr_id': 203}, {'value': 10, ...       270
# Smoothie King  [{'value': 5, 'attr_id': 203}, {'value': 1, 'a...       380
# Smoothie King  [{'value': 7, 'attr_id': 203}, {'value': 1, 'a...       330

# %%
#getting restaurant items out of all_food_df
#set restaurant as index
jamba_juice_df = all_food_df.set_index('Restaurant')
#located needed restaurant
jamba_juice_df = jamba_juice_df.loc[["Jamba Juice"]]
#set index to food name
jamba_juice_df = jamba_juice_df.set_index("Food_Name")
#search for 7 items we need
jamba_juice_df = jamba_juice_df.loc[["Razzmatazz Smoothie, Medium",
                                     "Chili Mango Smoothie, Medium",
                                     "Pomegranate Paradise Smoothie, Medium",
                                     "Aloha Pineapple Smoothie, Medium",
                                    "Watermelon Breeze Smoothie, Medium",
                                    "Strawberries Wild Smoothie, Medium",
                                    "Strawberry Whirl Smoothie, Medium"]]
#put 7 items into dataframe and reset index
jamba_juice_items_df = jamba_juice_df.reset_index()
#added restaurant column back
jamba_juice_items_df["Restaurant"] = 'Jamba Juice'
#set the index back to restaurant
jamba_juice_items_df = jamba_juice_items_df.set_index("Restaurant")
jamba_juice_items_df
# Out:
#                                          Food_Name  \
# Restaurant
# Jamba Juice            Razzmatazz Smoothie, Medium
# Jamba Juice           Chili Mango Smoothie, Medium
# Jamba Juice  Pomegranate Paradise Smoothie, Medium
# Jamba Juice       Aloha Pineapple Smoothie, Medium
# Jamba Juice     Watermelon Breeze Smoothie, Medium
# Jamba Juice     Strawberries Wild Smoothie, Medium
# Jamba Juice      Strawberry Whirl Smoothie, Medium
#
#                                                      Nutrients  Calories
# Restaurant
# Jamba Juice  [{'value': 3, 'attr_id': 203}, {'value': 1.5, ...       390
# Jamba Juice  [{'value': 3, 'attr_id': 203}, {'value': 2, 'a...       410
# Jamba Juice  [{'value': 2, 'attr_id': 203}, {'value': 0.5, ...       360
# Jamba Juice  [{'value': 8, 'attr_id': 203}, {'value': 1.5, ...       410
# Jamba Juice  [{'value': 3, 'attr_id': 203}, {'value': 1.5, ...       420
# Jamba Juice  [{'value': 5, 'attr_id': 203}, {'value': 0, 'a...       370
# Jamba Juice  [{'value': 2, 'attr_id': 203}, {'value': 0.5, ...       310

# %%
#getting restaurant items out of all_food_df
#set restaurant as index
mcalisters_deli_df = all_food_df.set_index('Restaurant')
#located needed restaurant
mcalisters_deli_df = mcalisters_deli_df.loc[["McAlister's Deli"]]
#set index to food name
mcalisters_deli_df = mcalisters_deli_df.set_index("Food_Name")
#search for 7 items we need
mcalisters_deli_df = mcalisters_deli_df.loc[["Garden Salad",
                                    "Grilled Chicken Sandwich",
                                    "Savannah Chopped Salad",
                                    "Italian Chopped Salad",
                                    "Garden Fresh Turkey Sandwich",
                                    "French Onion Chicken Sandwich",
                                    "Southwest Chicken & Avocado Salad"]]
#put 7 items into dataframe and reset index
mcalisters_deli_items_df = mcalisters_deli_df.reset_index()
#added restaurant column back
mcalisters_deli_items_df["Restaurant"] = "McAlister's Deli"
#set the index back to restaurant
mcalisters_deli_items_df = mcalisters_deli_items_df.set_index("Restaurant")
mcalisters_deli_items_df
# Out:
#                                           Food_Name  \
# Restaurant
# McAlister's Deli                       Garden Salad
# McAlister's Deli           Grilled Chicken Sandwich
# McAlister's Deli             Savannah Chopped Salad
# McAlister's Deli              Italian Chopped Salad
# McAlister's Deli       Garden Fresh Turkey Sandwich
# McAlister's Deli      French Onion Chicken Sandwich
# McAlister's Deli  Southwest Chicken & Avocado Salad
#
#                                                           Nutrients  Calories
# Restaurant
# McAlister's Deli  [{'value': 18, 'attr_id': 203}, {'value': 19, ...       310
# McAlister's Deli  [{'value': 41, 'attr_id': 203}, {'value': 23, ...       560
# McAlister's Deli  [{'value': 40, 'attr_id': 203}, {'value': 16, ...       480
# McAlister's Deli  [{'value': 33, 'attr_id': 203}, {'value': 42, ...       570
# McAlister's Deli  [{'value': 36, 'attr_id': 203}, {'value': 23, ...       670
# McAlister's Deli  [{'value': 50, 'attr_id': 203}, {'value': 34, ...       810
# McAlister's Deli  [{'value': 50, 'attr_id': 203}, {'value': 32, ...       630

# %%
#getting restaurant items out of all_food_df
#set restaurant as index
saladworks_df = all_food_df.set_index('Restaurant')
#located needed restaurant
saladworks_df = saladworks_df.loc[["Saladworks"]]
#set index to food name
saladworks_df = saladworks_df.set_index("Food_Name")
#search for 7 items we need
saladworks_df = saladworks_df.loc[["Tivoli",
                                    "Sophie's Salad",
                                    "Buffalo Chicken Panini",
                                    "Chicken Caesar",
                                    "Cobb",
                                    "Turkey Melt",
                                    "Mandarin Chicken"]]
#put 7 items into dataframe and reset index
saladworks_items_df = saladworks_df.reset_index()
#added restaurant column back
saladworks_items_df["Restaurant"] = "Saladworks"
#set the index back to restaurant
saladworks_items_df = saladworks_items_df.set_index("Restaurant")
saladworks_items_df
# Out:
#                          Food_Name  \
# Restaurant
# Saladworks                  Tivoli
# Saladworks          Sophie's Salad
# Saladworks  Buffalo Chicken Panini
# Saladworks          Chicken Caesar
# Saladworks                    Cobb
# Saladworks             Turkey Melt
# Saladworks        Mandarin Chicken
#
#                                                     Nutrients  Calories
# Restaurant
# Saladworks  [{'value': 33, 'attr_id': 203}, {'value': 19, ...       430
# Saladworks  [{'value': 12, 'attr_id': 203}, {'value': 14, ...       310
# Saladworks  [{'value': 43, 'attr_id': 203}, {'value': 29, ...       660
# Saladworks  [{'value': 42, 'attr_id': 203}, {'value': 4, '...       290
# Saladworks  [{'value': 23, 'attr_id': 203}, {'value': 16, ...       270
# Saladworks  [{'value': 47, 'attr_id': 203}, {'value': 40, ...       800
# Saladworks  [{'value': 12, 'attr_id': 203}, {'value': 7, '...       230

# %%
#combined all dfs into one
all_menu_items = panerabread_items_df.append(smoothie_king_items_df, sort=False)
all_menu_items = all_menu_items.append(jamba_juice_items_df,sort=False) 
all_menu_items = all_menu_items.append(mcalisters_deli_items_df,sort=False) 
all_menu_items = all_menu_items.append(saladworks_items_df,sort=False) 
all_menu_items
# Out:
#                                                           Food_Name  \
# Restaurant
# Panera Bread                       Caesar Salad with Chicken, Whole
# Panera Bread      Mediterranean Veggie Sandwich on Tomato Basil,...
# Panera Bread      Napa Almond Chicken Salad Sandwich on Country ...
# Panera Bread                   Fuji Apple Salad with Chicken, Whole
# Panera Bread                  Modern Greek Salad with Quinoa, Whole
# Panera Bread      Bacon Turkey Bravo Sandwich on Tomato Basil, W...
# Panera Bread                                 Green Passion Smoothie
# Smoothie King                              Lean1 Chocolate Smoothie
# Smoothie King                                    Gladiator Smoothie
# Smoothie King                             Lean1 Strawberry Smoothie
# Smoothie King                                  Berry Punch Smoothie
# Smoothie King                                Lean1 Vanilla Smoothie
# Smoothie King                               Immune Builder Smoothie
# Smoothie King                             Blueberry Heaven Smoothie
# Jamba Juice                             Razzmatazz Smoothie, Medium
# Jamba Juice                            Chili Mango Smoothie, Medium
# Jamba Juice                   Pomegranate Paradise Smoothie, Medium
# Jamba Juice                        Aloha Pineapple Smoothie, Medium
# Jamba Juice                      Watermelon Breeze Smoothie, Medium
# Jamba Juice                      Strawberries Wild Smoothie, Medium
# Jamba Juice                       Strawberry Whirl Smoothie, Medium
# McAlister's Deli                                       Garden Salad
# McAlister's Deli                           Grilled Chicken Sandwich
# McAlister's Deli                             Savannah Chopped Salad
# McAlister's Deli                              Italian Chopped Salad
# McAlister's Deli                       Garden Fresh Turkey Sandwich
# McAlister's Deli                      French Onion Chicken Sandwich
# McAlister's Deli                  Southwest Chicken & Avocado Salad
# Saladworks                                                   Tivoli
# Saladworks                                           Sophie's Salad
# Saladworks                                   Buffalo Chicken Panini
# Saladworks                                           Chicken Caesar
# Saladworks                                                     Cobb
# Saladworks                                              Turkey Melt
# Saladworks                                         Mandarin Chicken
#
#                                                           Nutrients  Calories
# Restaurant
# Panera Bread      [{'value': 35, 'attr_id': 203}, {'value': 27, ...       450
# Panera Bread      [{'value': 18, 'attr_id': 203}, {'value': 13, ...       440
# Panera Bread      [{'value': 28, 'attr_id': 203}, {'value': 32, ...       630
# Panera Bread      [{'value': 33, 'attr_id': 203}, {'value': 35, ...       570
# Panera Bread      [{'value': 12, 'attr_id': 203}, {'value': 43, ...       530
# Panera Bread      [{'value': 46, 'attr_id': 203}, {'value': 24, ...       630
# Panera Bread      [{'value': 2, 'attr_id': 203}, {'value': 0, 'a...       200
# Smoothie King     [{'value': 22, 'attr_id': 203}, {'value': 11, ...       290
# Smoothie King     [{'value': 45, 'attr_id': 203}, {'value': 0, '...       180
# Smoothie King     [{'value': 20, 'attr_id': 203}, {'value': 6, '...       280
# Smoothie King     [{'value': 0, 'attr_id': 203}, {'value': 0, 'a...       360
# Smoothie King     [{'value': 22, 'attr_id': 203}, {'value': 10, ...       270
# Smoothie King     [{'value': 5, 'attr_id': 203}, {'value': 1, 'a...       380
# Smoothie King     [{'value': 7, 'attr_id': 203}, {'value': 1, 'a...       330
# Jamba Juice       [{'value': 3, 'attr_id': 203}, {'value': 1.5, ...       390
# Jamba Juice       [{'value': 3, 'attr_id': 203}, {'value': 2, 'a...       410
# Jamba Juice       [{'value': 2, 'attr_id': 203}, {'value': 0.5, ...       360
# Jamba Juice       [{'value': 8, 'attr_id': 203}, {'value': 1.5, ...       410
# Jamba Juice       [{'value': 3, 'attr_id': 203}, {'value': 1.5, ...       420
# Jamba Juice       [{'value': 5, 'attr_id': 203}, {'value': 0, 'a...       370
# Jamba Juice       [{'value': 2, 'attr_id': 203}, {'value': 0.5, ...       310
# McAlister's Deli  [{'value': 18, 'attr_id': 203}, {'value': 19, ...       310
# McAlister's Deli  [{'value': 41, 'attr_id': 203}, {'value': 23, ...       560
# McAlister's Deli  [{'value': 40, 'attr_id': 203}, {'value': 16, ...       480
# McAlister's Deli  [{'value': 33, 'attr_id': 203}, {'value': 42, ...       570
# McAlister's Deli  [{'value': 36, 'attr_id': 203}, {'value': 23, ...       670
# McAlister's Deli  [{'value': 50, 'attr_id': 203}, {'value': 34, ...       810
# McAlister's Deli  [{'value': 50, 'attr_id': 203}, {'value': 32, ...       630
# Saladworks        [{'value': 33, 'attr_id': 203}, {'value': 19, ...       430
# Saladworks        [{'value': 12, 'attr_id': 203}, {'value': 14, ...       310
# Saladworks        [{'value': 43, 'attr_id': 203}, {'value': 29, ...       660
# Saladworks        [{'value': 42, 'attr_id': 203}, {'value': 4, '...       290
# Saladworks        [{'value': 23, 'attr_id': 203}, {'value': 16, ...       270
# Saladworks        [{'value': 47, 'attr_id': 203}, {'value': 40, ...       800
# Saladworks        [{'value': 12, 'attr_id': 203}, {'value': 7, '...       230

# %%
all_menu_items.to_csv("output/all_menu_items.csv", index=False, header=True)
